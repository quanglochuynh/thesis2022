# %%
import pathlib
import tensorflow as tf
from tensorflow import keras
from keras import layers
# import numpy

img_height = 224
img_width = 224
input_shape = (img_width, img_height, 3)
batch_size = 8
train_dir = pathlib.Path('D:/Thesis_data/training_img')
test_dir  = pathlib.Path('D:/Thesis_data/testing_img')
model_dir = pathlib.Path('D:/Thesis_data/Kaggle_backup/cacao_CAE/model.h5')

# %%
train_ds = keras.utils.image_dataset_from_directory(
  train_dir,
  labels="inferred",
  label_mode="categorical",
    seed=252,
  shuffle=True,
    validation_split=0.2,
    subset="training",
  image_size=(img_height, img_width),
  batch_size=batch_size
)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Found 13272 files belonging to 14 classes.
# Using 10618 files for training.

# %%
model = keras.models.load_model(model_dir)
model.summary()
# model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# Model: "model_198"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_47 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  rescaling_287 (Rescaling)   (None, 224, 224, 3)       0
#
#  conv2d_979 (Conv2D)         (None, 218, 218, 84)      12432
#
#  leaky_re_lu_831 (LeakyReLU)  (None, 218, 218, 84)     0
#
#  conv2d_980 (Conv2D)         (None, 206, 206, 42)      596274
#
#  leaky_re_lu_832 (LeakyReLU)  (None, 206, 206, 42)     0
#
#  max_pooling2d_692 (MaxPooli  (None, 103, 103, 42)     0
#  ng2D)
#
#  conv2d_981 (Conv2D)         (None, 95, 95, 42)        142926
#
#  leaky_re_lu_833 (LeakyReLU)  (None, 95, 95, 42)       0
#
#  max_pooling2d_693 (MaxPooli  (None, 47, 47, 42)       0
#  ng2D)
#
#  conv2d_982 (Conv2D)         (None, 43, 43, 28)        29428
#
#  leaky_re_lu_834 (LeakyReLU)  (None, 43, 43, 28)       0
#
#  max_pooling2d_694 (MaxPooli  (None, 21, 21, 28)       0
#  ng2D)
#
#  conv2d_983 (Conv2D)         (None, 19, 19, 28)        7084
#
#  leaky_re_lu_835 (LeakyReLU)  (None, 19, 19, 28)       0
#
#  max_pooling2d_695 (MaxPooli  (None, 9, 9, 28)         0
#  ng2D)
#
#  conv2d_984 (Conv2D)         (None, 7, 7, 14)          3542
#
#  leaky_re_lu_836 (LeakyReLU)  (None, 7, 7, 14)         0
#
#  flatten_137 (Flatten)       (None, 686)               0
#
#  dense_952 (Dense)           (None, 686)               471282
#
#  dense_953 (Dense)           (None, 343)               235641
#
#  dense_954 (Dense)           (None, 112)               38528
#
#  dense_955 (Dense)           (None, 56)                6328
#
#  dense_956 (Dense)           (None, 112)               6384
#
#  dense_957 (Dense)           (None, 343)               38759
#
#  dense_958 (Dense)           (None, 686)               235984
#
#  reshape_137 (Reshape)       (None, 7, 7, 14)          0
#
#  conv2d_transpose_836 (Conv2  (None, 14, 14, 14)       1778
#  DTranspose)
#
#  conv2d_transpose_837 (Conv2  (None, 28, 28, 28)       3556
#  DTranspose)
#
#  conv2d_transpose_838 (Conv2  (None, 56, 56, 28)       19628
#  DTranspose)
#
#  conv2d_transpose_839 (Conv2  (None, 112, 112, 42)     95298
#  DTranspose)
#
#  conv2d_transpose_840 (Conv2  (None, 224, 224, 42)     298158
#  DTranspose)
#
#  conv2d_transpose_841 (Conv2  (None, 224, 224, 84)     172956
#  DTranspose)
#
#  conv2d_985 (Conv2D)         (None, 224, 224, 3)       6303
#
#  rescaling_288 (Rescaling)   (None, 224, 224, 3)       0
#
# =================================================================
# Total params: 2,422,269
# Trainable params: 2,422,269
# Non-trainable params: 0
# _________________________________________________________________

# %%
input_layer = layers.Input(shape=input_shape)
input_layer2 = layers.Rescaling(scale=1./255, offset=0)(input_layer)
# encoder
x = layers.Conv2D(84, kernel_size=(7,7))(input_layer2)
x = layers.LeakyReLU(alpha=0.1)(x)

x = layers.Conv2D(42, kernel_size=(13,13))(x)
x = layers.LeakyReLU(alpha=0.1)(x)
x = layers.MaxPooling2D(pool_size=(2,2), strides=2)(x)

x = layers.Conv2D(42, kernel_size=(9,9))(x)
x = layers.LeakyReLU(alpha=0.1)(x)
x = layers.MaxPooling2D(pool_size=(2,2), strides=2)(x)

x = layers.Conv2D(28, kernel_size=(5,5))(x)
x = layers.LeakyReLU(alpha=0.1)(x)
x = layers.MaxPooling2D(pool_size=(2,2), strides=2)(x)

x = layers.Conv2D(28, kernel_size=(3,3))(x)   # (14,14,14)
x = layers.LeakyReLU(alpha=0.1)(x)
x = layers.MaxPooling2D(pool_size=(2,2), strides=2)(x)

x = layers.Conv2D(14, kernel_size=(3,3))(x)   # (7,7,14)
x = layers.LeakyReLU(alpha=0.1)(x)
#     x = layers.MaxPooling2D(pool_size=(2,2), strides=2)(x)


x = layers.Flatten()(x)
x = layers.Dense(686, activation="relu")(x)
x = layers.Dense(343, activation="relu")(x)
x = layers.Dense(112, activation="relu")(x)
# #latent
latent = layers.Dense(56, activation="softmax")(x)
output_layer = layers.Dense(14, activation="softmax")(latent)

cnn = keras.Model(input_layer, output_layer)

for i in range(22):
    cnn.trainable_weights[i] = model.trainable_weights[i]

# cnn.layers.append(layers.Dense(14, activation="softmax"))
cnn.summary()
cnn.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  rescaling_5 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_30 (Conv2D)          (None, 218, 218, 84)      12432
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 218, 218, 84)      0
#
#  conv2d_31 (Conv2D)          (None, 206, 206, 42)      596274
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 206, 206, 42)      0
#
#  max_pooling2d_20 (MaxPoolin  (None, 103, 103, 42)     0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 95, 95, 42)        142926
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 95, 95, 42)        0
#
#  max_pooling2d_21 (MaxPoolin  (None, 47, 47, 42)       0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 43, 43, 28)        29428
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 43, 43, 28)        0
#
#  max_pooling2d_22 (MaxPoolin  (None, 21, 21, 28)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 19, 19, 28)        7084
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 19, 19, 28)        0
#
#  max_pooling2d_23 (MaxPoolin  (None, 9, 9, 28)         0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 7, 7, 14)          3542
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 7, 7, 14)          0
#
#  flatten_5 (Flatten)         (None, 686)               0
#
#  dense_35 (Dense)            (None, 686)               471282
#
#  dense_36 (Dense)            (None, 343)               235641
#
#  dense_37 (Dense)            (None, 112)               38528
#
#  dense_38 (Dense)            (None, 56)                6328
#
#  dense_39 (Dense)            (None, 14)                798
#
# =================================================================
# Total params: 1,544,263
# Trainable params: 1,544,263
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn.save(pathlib.Path('D:/Thesis_data/Kaggle_backup/cacao_CAE/CNN_converted.h5'))
