# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt
from image_extractor import DataSetup
data = DataSetup()
# Out:
# OS: Windows
# 0 :  overall_geometry
# 1 :  overall_rgb
# 2 :  overall_hsv
# 3 :  color_grid
# 4 :  glcm_grid
# 5 :  comp_hsv
# 6 :  lbp_hist
# 7 :  haralick
# 8 :  red_haralick
# 9 :  blue_haralick

# %%
data.concat(dataID=[0, 5, 6, 7, 8, 9])
model_dir = 'D:./TF_backup/mlp/2_' + data.model_name
checkpoint_dir = 'D:./TF_checkpoint/mlp/weight/'
print(model_dir)

input_shape = (data.length,)
batch_size = 8

model_checkpoint = keras.callbacks.ModelCheckpoint(
    checkpoint_dir,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
)
# Out:
# x_test size: (1260, 267)
# x_train size: (7140, 267)
# y_test size: (1260, 14)
# y_train size: (7140, 14)
# Model name = ' overall_geometry_comp_hsv_lbp_hist_haralick_red_haralick_blue_haralick.h5 '
# D:./TF_backup/mlp/2_overall_geometry_comp_hsv_lbp_hist_haralick_red_haralick_blue_haralick.h5

# %%
normalizer = layers.Normalization()
normalizer.adapt(data.x_train)

# Define model
input_layer = layers.Input(shape=input_shape)
norm = normalizer(input_layer)
den1 = layers.Dense(512, activation='tanh', kernel_initializer='HeNormal')(norm)
drop1 = layers.Dropout(0.3)(den1)
den2 = layers.Dense(512, activation='tanh', kernel_initializer='HeNormal')(drop1)
drop2 = layers.Dropout(0.3)(den2)
den3 = layers.Dense(512, activation='tanh', kernel_initializer='HeNormal')(drop2)
drop3 = layers.Dropout(0.3)(den3)
# den4 = layers.Dense(512, activation='tanh', kernel_initializer='HeNormal')(drop3)
# drop4 = layers.Dropout(0.2)(den4)
den5 = layers.Dense(14, activation='softmax')(drop3)
model = keras.Model(input_layer, den5)

model.compile(
    optimizer="adam", 
    loss="categorical_crossentropy", 
    metrics=["accuracy"]
    )

# model = keras.models.load_model(model_dir)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 267)]             0
#
#  normalization (Normalizatio  (None, 267)              535
#  n)
#
#  dense (Dense)               (None, 512)               137216
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 14)                7182
#
# =================================================================
# Total params: 670,245
# Trainable params: 669,710
# Non-trainable params: 535
# _________________________________________________________________

# %%
epochs = 20
history = model.fit(data.x_train, data.y_train, batch_size=8, shuffle=True, epochs=epochs, callbacks=[model_checkpoint])
model.save(model_dir)
# Out:
# Epoch 1/20
# 893/893 [==============================] - 5s 5ms/step - loss: 1.1617 - accuracy: 0.6178
# Epoch 2/20
# 893/893 [==============================] - 4s 4ms/step - loss: 0.7543 - accuracy: 0.7345
# Epoch 3/20
# 893/893 [==============================] - 4s 4ms/step - loss: 0.6683 - accuracy: 0.7612
# Epoch 4/20
# 893/893 [==============================] - 4s 4ms/step - loss: 0.6013 - accuracy: 0.7859
# Epoch 5/20
# 893/893 [==============================] - 4s 4ms/step - loss: 0.5515 - accuracy: 0.8031
# Epoch 6/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.5282 - accuracy: 0.8125
# Epoch 7/20
# 893/893 [==============================] - 4s 4ms/step - loss: 0.4692 - accuracy: 0.8291
# Epoch 8/20
# 893/893 [==============================] - 4s 4ms/step - loss: 0.4631 - accuracy: 0.8382
# Epoch 9/20
# 893/893 [==============================] - 4s 4ms/step - loss: 0.4554 - accuracy: 0.8382
# Epoch 10/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.4407 - accuracy: 0.8436
# Epoch 11/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3953 - accuracy: 0.8622
# Epoch 12/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3917 - accuracy: 0.8606
# Epoch 13/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3627 - accuracy: 0.8732
# Epoch 14/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3775 - accuracy: 0.8675
# Epoch 15/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3621 - accuracy: 0.8742
# Epoch 16/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3461 - accuracy: 0.8758
# Epoch 17/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3403 - accuracy: 0.8829
# Epoch 18/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3422 - accuracy: 0.8835
# Epoch 19/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3178 - accuracy: 0.8854
# Epoch 20/20
# 893/893 [==============================] - 4s 5ms/step - loss: 0.3431 - accuracy: 0.8835

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])

# %%
score = model.evaluate(data.x_test, data.y_test, verbose=1)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# 40/40 [==============================] - 0s 5ms/step - loss: 1.1686 - accuracy: 0.7151
# Test loss: 1.1685855388641357
# Test accuracy: 0.7150793671607971

# %%
classes_name = ['Agglutinated', 'Brittle', 'Compartmentalized_Brown', 'Compartmentalized_PartiallyPurple', 'Compartmentalized_Purple', 'Compartmentalized_Slaty', 'Compartmentalized_White', 'Flattened', 'Moldered', 'Plated_Brown', 'Plated_PartiallyPurple', 'Plated_Purple', 'Plated_Slaty', 'Plated_White']

i = 0
cmatrix = np.zeros((14,14), dtype=np.int16)
bat = int(len(data.x_test)/14)
n=0
for i in range(0, len(data.x_test),bat):
    print(n)
    result = model.predict_on_batch(data.x_test[i:i+bat])
    ans = data.y_test[i:i+bat]
    for j in range(bat):
        id1 = np.argmax(result[j])
        id2 = np.argmax(ans[j])
        cmatrix[id1, id2] = cmatrix[id1][id2] + 1
        if (id1!=id2):
            print(classes_name[int(n)], j+1, classes_name[id1])
    n=n+1

cmatrix = np.absolute(cmatrix)
# print(repr(cmatrix))

fig = plt.figure(figsize=(6,6))
plt.imshow(cmatrix)
plt.title("Plot 2D array")
plt.show()
# Out:
# 0
# Agglutinated 2 Brittle
# Agglutinated 3 Brittle
# Agglutinated 4 Brittle
# Agglutinated 25 Moldered
# Agglutinated 26 Moldered
# Agglutinated 27 Moldered
# Agglutinated 28 Moldered
# Agglutinated 43 Brittle
# Agglutinated 51 Plated_White
# Agglutinated 53 Plated_White
# Agglutinated 54 Plated_White
# Agglutinated 80 Brittle
# Agglutinated 85 Plated_Brown
# Agglutinated 86 Moldered
# Agglutinated 87 Brittle
# Agglutinated 88 Moldered
# Agglutinated 89 Moldered
# Agglutinated 90 Brittle
# 1
# Brittle 5 Agglutinated
# Brittle 6 Agglutinated
# Brittle 7 Moldered
# Brittle 14 Agglutinated
# Brittle 32 Flattened
# Brittle 37 Agglutinated
# Brittle 38 Agglutinated
# Brittle 39 Agglutinated
# Brittle 40 Agglutinated
# Brittle 41 Agglutinated
# Brittle 42 Agglutinated
# Brittle 43 Agglutinated
# Brittle 44 Agglutinated
# Brittle 45 Agglutinated
# Brittle 46 Agglutinated
# Brittle 47 Agglutinated
# Brittle 48 Agglutinated
# Brittle 49 Flattened
# Brittle 50 Flattened
# Brittle 53 Flattened
# Brittle 54 Flattened
# Brittle 69 Plated_Brown
# Brittle 71 Plated_Brown
# Brittle 72 Moldered
# Brittle 73 Agglutinated
# Brittle 74 Agglutinated
# Brittle 75 Agglutinated
# Brittle 76 Flattened
# Brittle 77 Agglutinated
# Brittle 78 Agglutinated
# 2
# Compartmentalized_Brown 1 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 2 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 3 Compartmentalized_White
# Compartmentalized_Brown 4 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 5 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 6 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 11 Plated_Brown
# Compartmentalized_Brown 12 Plated_Brown
# Compartmentalized_Brown 16 Plated_Brown
# Compartmentalized_Brown 25 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 26 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 27 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 28 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 29 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 30 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 32 Moldered
# Compartmentalized_Brown 33 Compartmentalized_White
# Compartmentalized_Brown 36 Moldered
# Compartmentalized_Brown 41 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 47 Plated_Brown
# Compartmentalized_Brown 61 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 63 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 64 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 65 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 66 Compartmentalized_PartiallyPurple
# Compartmentalized_Brown 67 Compartmentalized_Slaty
# Compartmentalized_Brown 68 Moldered
# Compartmentalized_Brown 70 Compartmentalized_Slaty
# Compartmentalized_Brown 71 Moldered
# Compartmentalized_Brown 72 Moldered
# Compartmentalized_Brown 73 Moldered
# Compartmentalized_Brown 74 Moldered
# Compartmentalized_Brown 75 Moldered
# Compartmentalized_Brown 76 Moldered
# Compartmentalized_Brown 78 Moldered
# Compartmentalized_Brown 82 Moldered
# 3
# Compartmentalized_PartiallyPurple 19 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 20 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 21 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 22 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 23 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 24 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 25 Plated_PartiallyPurple
# Compartmentalized_PartiallyPurple 26 Plated_PartiallyPurple
# Compartmentalized_PartiallyPurple 27 Plated_PartiallyPurple
# Compartmentalized_PartiallyPurple 28 Plated_PartiallyPurple
# Compartmentalized_PartiallyPurple 29 Plated_PartiallyPurple
# Compartmentalized_PartiallyPurple 30 Plated_PartiallyPurple
# Compartmentalized_PartiallyPurple 31 Compartmentalized_Brown
# Compartmentalized_PartiallyPurple 32 Compartmentalized_Brown
# Compartmentalized_PartiallyPurple 33 Compartmentalized_Brown
# Compartmentalized_PartiallyPurple 34 Compartmentalized_Brown
# Compartmentalized_PartiallyPurple 35 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 36 Compartmentalized_Brown
# Compartmentalized_PartiallyPurple 37 Plated_Brown
# Compartmentalized_PartiallyPurple 38 Plated_PartiallyPurple
# Compartmentalized_PartiallyPurple 39 Plated_Brown
# Compartmentalized_PartiallyPurple 40 Plated_Brown
# Compartmentalized_PartiallyPurple 41 Plated_Brown
# Compartmentalized_PartiallyPurple 42 Plated_PartiallyPurple
# Compartmentalized_PartiallyPurple 43 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 44 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 45 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 46 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 47 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 48 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 52 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 65 Compartmentalized_Brown
# Compartmentalized_PartiallyPurple 75 Moldered
# Compartmentalized_PartiallyPurple 78 Moldered
# Compartmentalized_PartiallyPurple 79 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 81 Compartmentalized_Purple
# Compartmentalized_PartiallyPurple 84 Compartmentalized_Brown
# Compartmentalized_PartiallyPurple 86 Moldered
# 4
# Compartmentalized_Purple 19 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 20 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 21 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 22 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 23 Plated_PartiallyPurple
# Compartmentalized_Purple 24 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 31 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 35 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 40 Plated_Purple
# Compartmentalized_Purple 46 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 48 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 49 Compartmentalized_PartiallyPurple
# Compartmentalized_Purple 55 Plated_PartiallyPurple
# Compartmentalized_Purple 56 Plated_PartiallyPurple
# Compartmentalized_Purple 57 Plated_PartiallyPurple
# Compartmentalized_Purple 58 Plated_PartiallyPurple
# Compartmentalized_Purple 59 Plated_PartiallyPurple
# Compartmentalized_Purple 60 Plated_PartiallyPurple
# Compartmentalized_Purple 73 Plated_PartiallyPurple
# Compartmentalized_Purple 75 Plated_PartiallyPurple
# Compartmentalized_Purple 76 Plated_PartiallyPurple
# Compartmentalized_Purple 77 Plated_PartiallyPurple
# Compartmentalized_Purple 78 Plated_PartiallyPurple
# 5
# Compartmentalized_Slaty 67 Moldered
# Compartmentalized_Slaty 68 Moldered
# Compartmentalized_Slaty 69 Moldered
# Compartmentalized_Slaty 70 Plated_Purple
# Compartmentalized_Slaty 71 Plated_Purple
# Compartmentalized_Slaty 72 Compartmentalized_Purple
# 6
# Compartmentalized_White 9 Plated_White
# Compartmentalized_White 31 Plated_White
# Compartmentalized_White 32 Plated_White
# Compartmentalized_White 33 Plated_White
# 7
# Flattened 20 Brittle
# Flattened 24 Plated_Slaty
# Flattened 46 Brittle
# Flattened 48 Brittle
# 8
# 9
# Plated_Brown 1 Compartmentalized_PartiallyPurple
# Plated_Brown 2 Compartmentalized_PartiallyPurple
# Plated_Brown 3 Compartmentalized_PartiallyPurple
# Plated_Brown 4 Compartmentalized_PartiallyPurple
# Plated_Brown 5 Compartmentalized_PartiallyPurple
# Plated_Brown 6 Compartmentalized_PartiallyPurple
# Plated_Brown 14 Compartmentalized_PartiallyPurple
# Plated_Brown 16 Compartmentalized_PartiallyPurple
# Plated_Brown 25 Plated_PartiallyPurple
# Plated_Brown 27 Compartmentalized_PartiallyPurple
# Plated_Brown 29 Plated_PartiallyPurple
# Plated_Brown 30 Plated_PartiallyPurple
# Plated_Brown 31 Compartmentalized_PartiallyPurple
# Plated_Brown 32 Compartmentalized_PartiallyPurple
# Plated_Brown 35 Compartmentalized_PartiallyPurple
# Plated_Brown 36 Compartmentalized_PartiallyPurple
# Plated_Brown 37 Plated_PartiallyPurple
# Plated_Brown 38 Plated_PartiallyPurple
# Plated_Brown 39 Plated_PartiallyPurple
# Plated_Brown 40 Plated_PartiallyPurple
# Plated_Brown 41 Plated_PartiallyPurple
# Plated_Brown 42 Plated_PartiallyPurple
# Plated_Brown 43 Compartmentalized_PartiallyPurple
# Plated_Brown 44 Compartmentalized_PartiallyPurple
# Plated_Brown 45 Compartmentalized_PartiallyPurple
# Plated_Brown 46 Compartmentalized_PartiallyPurple
# Plated_Brown 48 Compartmentalized_PartiallyPurple
# Plated_Brown 50 Plated_PartiallyPurple
# Plated_Brown 52 Plated_PartiallyPurple
# Plated_Brown 53 Compartmentalized_PartiallyPurple
# Plated_Brown 54 Plated_PartiallyPurple
# Plated_Brown 61 Plated_PartiallyPurple
# Plated_Brown 63 Plated_PartiallyPurple
# Plated_Brown 68 Plated_PartiallyPurple
# Plated_Brown 69 Plated_PartiallyPurple
# Plated_Brown 71 Plated_PartiallyPurple
# Plated_Brown 73 Plated_PartiallyPurple
# Plated_Brown 74 Plated_PartiallyPurple
# Plated_Brown 75 Plated_PartiallyPurple
# Plated_Brown 76 Plated_PartiallyPurple
# Plated_Brown 77 Plated_PartiallyPurple
# Plated_Brown 78 Plated_PartiallyPurple
# Plated_Brown 79 Plated_PartiallyPurple
# Plated_Brown 80 Plated_PartiallyPurple
# Plated_Brown 81 Plated_PartiallyPurple
# Plated_Brown 82 Plated_PartiallyPurple
# Plated_Brown 85 Compartmentalized_PartiallyPurple
# Plated_Brown 86 Compartmentalized_PartiallyPurple
# Plated_Brown 87 Compartmentalized_PartiallyPurple
# Plated_Brown 88 Plated_PartiallyPurple
# Plated_Brown 89 Plated_PartiallyPurple
# 10
# Plated_PartiallyPurple 1 Plated_Purple
# Plated_PartiallyPurple 2 Plated_Purple
# Plated_PartiallyPurple 3 Plated_Purple
# Plated_PartiallyPurple 4 Plated_Purple
# Plated_PartiallyPurple 5 Plated_Purple
# Plated_PartiallyPurple 6 Plated_Purple
# Plated_PartiallyPurple 8 Compartmentalized_PartiallyPurple
# Plated_PartiallyPurple 9 Compartmentalized_PartiallyPurple
# Plated_PartiallyPurple 12 Compartmentalized_PartiallyPurple
# Plated_PartiallyPurple 13 Plated_Purple
# Plated_PartiallyPurple 14 Plated_Purple
# Plated_PartiallyPurple 15 Plated_Purple
# Plated_PartiallyPurple 16 Plated_Purple
# Plated_PartiallyPurple 17 Plated_Purple
# Plated_PartiallyPurple 18 Plated_Purple
# Plated_PartiallyPurple 25 Plated_Purple
# Plated_PartiallyPurple 26 Plated_Purple
# Plated_PartiallyPurple 31 Compartmentalized_Purple
# Plated_PartiallyPurple 32 Plated_Purple
# Plated_PartiallyPurple 33 Plated_Purple
# Plated_PartiallyPurple 34 Compartmentalized_Purple
# Plated_PartiallyPurple 35 Compartmentalized_Purple
# Plated_PartiallyPurple 37 Plated_Purple
# Plated_PartiallyPurple 38 Plated_Purple
# Plated_PartiallyPurple 39 Plated_Purple
# Plated_PartiallyPurple 40 Plated_Purple
# Plated_PartiallyPurple 41 Plated_Purple
# Plated_PartiallyPurple 42 Plated_Purple
# Plated_PartiallyPurple 43 Plated_Purple
# Plated_PartiallyPurple 44 Plated_Purple
# Plated_PartiallyPurple 45 Plated_Purple
# Plated_PartiallyPurple 46 Plated_Purple
# Plated_PartiallyPurple 47 Plated_Purple
# Plated_PartiallyPurple 49 Compartmentalized_Purple
# Plated_PartiallyPurple 50 Compartmentalized_Purple
# Plated_PartiallyPurple 51 Compartmentalized_Purple
# Plated_PartiallyPurple 52 Compartmentalized_PartiallyPurple
# Plated_PartiallyPurple 53 Compartmentalized_Purple
# Plated_PartiallyPurple 54 Compartmentalized_Purple
# Plated_PartiallyPurple 56 Plated_Purple
# Plated_PartiallyPurple 57 Plated_Purple
# Plated_PartiallyPurple 58 Plated_Purple
# Plated_PartiallyPurple 67 Plated_Purple
# Plated_PartiallyPurple 68 Plated_Purple
# Plated_PartiallyPurple 69 Plated_Purple
# Plated_PartiallyPurple 70 Plated_Purple
# Plated_PartiallyPurple 71 Plated_Purple
# Plated_PartiallyPurple 72 Plated_Purple
# Plated_PartiallyPurple 73 Plated_Purple
# Plated_PartiallyPurple 74 Compartmentalized_PartiallyPurple
# Plated_PartiallyPurple 75 Plated_Brown
# Plated_PartiallyPurple 76 Plated_Brown
# Plated_PartiallyPurple 77 Plated_Brown
# Plated_PartiallyPurple 78 Plated_Brown
# Plated_PartiallyPurple 79 Plated_Brown
# Plated_PartiallyPurple 80 Plated_Brown
# Plated_PartiallyPurple 81 Plated_Brown
# Plated_PartiallyPurple 82 Plated_Brown
# Plated_PartiallyPurple 84 Plated_Brown
# Plated_PartiallyPurple 88 Plated_Purple
# 11
# Plated_Purple 1 Plated_PartiallyPurple
# Plated_Purple 3 Plated_PartiallyPurple
# Plated_Purple 4 Plated_PartiallyPurple
# Plated_Purple 6 Plated_PartiallyPurple
# Plated_Purple 7 Plated_PartiallyPurple
# Plated_Purple 8 Plated_PartiallyPurple
# Plated_Purple 9 Plated_PartiallyPurple
# Plated_Purple 26 Plated_PartiallyPurple
# Plated_Purple 31 Plated_PartiallyPurple
# Plated_Purple 33 Plated_PartiallyPurple
# Plated_Purple 40 Plated_PartiallyPurple
# Plated_Purple 51 Plated_PartiallyPurple
# Plated_Purple 53 Plated_PartiallyPurple
# Plated_Purple 80 Compartmentalized_Purple
# Plated_Purple 83 Compartmentalized_Purple
# Plated_Purple 84 Compartmentalized_Purple
# Plated_Purple 85 Plated_Brown
# Plated_Purple 86 Plated_PartiallyPurple
# Plated_Purple 87 Plated_Brown
# Plated_Purple 88 Plated_Brown
# Plated_Purple 89 Plated_Brown
# Plated_Purple 90 Plated_Brown
# 12
# Plated_Slaty 67 Compartmentalized_Slaty
# Plated_Slaty 68 Compartmentalized_Slaty
# Plated_Slaty 69 Compartmentalized_Slaty
# Plated_Slaty 70 Compartmentalized_Slaty
# Plated_Slaty 71 Compartmentalized_Slaty
# Plated_Slaty 72 Plated_Purple
# Plated_Slaty 74 Brittle
# Plated_Slaty 78 Brittle
# 13
# Plated_White 1 Compartmentalized_White
# Plated_White 2 Compartmentalized_White
# Plated_White 4 Compartmentalized_White
# Plated_White 6 Compartmentalized_White
# Plated_White 19 Plated_Brown
# Plated_White 21 Plated_PartiallyPurple
# Plated_White 22 Plated_PartiallyPurple
# Plated_White 24 Plated_PartiallyPurple
# Plated_White 45 Compartmentalized_White
# Plated_White 47 Compartmentalized_White

# %%
acc = []
for i in range(14):
    acc.append(np.round(cmatrix[i][i]/120,3))
    print(classes_name[i] + ': \t \t' + str(acc[i]))
print(np.mean(acc))
# Out:
# Agglutinated: 	 	0.65
# Brittle: 	 	0.483
# Compartmentalized_Brown: 	 	0.525
# Compartmentalized_PartiallyPurple: 	 	0.408
# Compartmentalized_Purple: 	 	0.542
# Compartmentalized_Slaty: 	 	0.7
# Compartmentalized_White: 	 	0.717
# Flattened: 	 	0.717
# Moldered: 	 	0.733
# Plated_Brown: 	 	0.417
# Plated_PartiallyPurple: 	 	0.283
# Plated_Purple: 	 	0.633
# Plated_Slaty: 	 	0.7
# Plated_White: 	 	0.683
# 0.5850714285714286
