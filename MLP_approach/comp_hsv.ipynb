# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8,8)

# %%
image_dir = "/Users/lochuynhquang/Desktop/Color_Corrected_512x512/Compartmentalized_PartiallyPurple/image (89).JPG"
img = plt.imread(image_dir)
img = img[100:412, 157:350,:]
img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
plt.imshow(img)
plt.show()

# %%
hist, bin = np.histogram(img, bins=np.linspace(8,255,32), density=True, normed=True)
# print(bin)
bi = np.linspace(1,32,32)
print(len(bi))
print(len(hist))
plt.bar(bi[0:31], hist)
plt.show()
# Out:
# 32
# 31
# /var/folders/d5/c4ygqh7n0m50m1cshpsjsg2m0000gn/T/ipykernel_3740/221968598.py:1: DeprecationWarning: The normed argument is ignored when density is provided. In future passing both will result in an error.
#   hist, bin = np.histogram(img, bins=np.linspace(8,255,32), density=True, normed=True)
